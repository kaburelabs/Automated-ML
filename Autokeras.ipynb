# %%
from keras.datasets import mnist

from autokeras import ImageClassifier

if __name__ == '__main__':
        (x_train, y_train), (x_test, y_test) = mnist.load_data()
        x_train = x_train.reshape(x_train.shape + (1,))
        x_test = x_test.reshape(x_test.shape + (1,))
        clf = ImageClassifier(verbose=True, augment=False)
        clf.fit(x_train, y_train, time_limit=12 * 60 * 60)
        clf.final_fit(x_train, y_train, x_test, y_test, retrain=True
        y = clf.evaluate(x_test, y_test)
        print(y * 100)
# Out:
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 0               |
# +----------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           0            |   1.5432168588042259   |        0.98996         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 1               |
# +----------------------------------------------+
# /home/leonardo/anaconda3/lib/python3.6/site-packages/autokeras/bayesian.py:151: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |           0            |          ('to_concat_skip_model', 1, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           1            |   1.529027494043112    |        0.99224         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 2               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |           1            |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 27, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           2            |   1.4133870037272573   |         0.9926         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 3               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |           1            |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 21, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           3            |   2.1135533556342123   |        0.99116         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 4               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |           2            |            ('to_wider_model', 5, 64)            |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_add_skip_model', 26, 32)          |
# |                        |         ('to_conv_deeper_model', 29, 3)         |
# |                        |          ('to_add_skip_model', 32, 29)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           4            |   1.7173215851187706   |   0.9917199999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 5               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |           2            |          ('to_conv_deeper_model', 5, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           5            |   1.4723245318979026   |        0.99168         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 6               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |           ('to_add_skip_model', 1, 23)          |
# |           2            |           ('to_add_skip_model', 1, 5)           |
# |                        |           ('to_add_skip_model', 5, 23)          |
# |                        |         ('to_concat_skip_model', 5, 23)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           6            |   1.593956859409809    |        0.99164         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 7               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |         ('to_conv_deeper_model', 26, 3)         |
# |                        |         ('to_concat_skip_model', 23, 26)        |
# |           2            |         ('to_concat_skip_model', 1, 23)         |
# |                        |         ('to_concat_skip_model', 23, 5)         |
# |                        |          ('to_add_skip_model', 26, 29)          |
# |                        |         ('to_conv_deeper_model', 29, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           7            |   1.4871533341705798   |   0.9918800000000001   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |               Training model 8               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |           2            |          ('to_conv_deeper_model', 9, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           8            |   1.6266540542244912   |        0.99164         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 9               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |           2            |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           9            |   2.290238896012306    |   0.9914799999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 10               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |            ('to_wider_model', 5, 64)            |
# |                        |            ('to_wider_model', 5, 128)           |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |           2            |            ('to_wider_model', 5, 256)           |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |          ('to_add_skip_model', 26, 32)          |
# |                        |           ('to_add_skip_model', 1, 26)          |
# |                        |         ('to_conv_deeper_model', 23, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           10           |   1.456376506201923    |        0.99232         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 11               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |           10           |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           11           |   1.5077181827276944   |        0.99156         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 12               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |           ('to_add_skip_model', 1, 5)           |
# |                        |            ('to_wider_model', 1, 64)            |
# |           2            |          ('to_conv_deeper_model', 9, 3)         |
# |                        |          ('to_concat_skip_model', 1, 9)         |
# |                        |         ('to_conv_deeper_model', 30, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           12           |   1.3046408547088504   |   0.9932000000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 13               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |           12           |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |         ('to_concat_skip_model', 1, 25)         |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |         ('to_concat_skip_model', 25, 33)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           13           |   1.5065297476947308   |        0.99176         |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 14               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |           12           |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |         ('to_conv_deeper_model', 44, 3)         |
# |                        |           ('to_add_skip_model', 1, 47)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           14           |   1.665447716601193    |        0.99292         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 15               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |           12           |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |         ('to_concat_skip_model', 1, 25)         |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |         ('to_concat_skip_model', 25, 33)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           15           |    1.59645436424762    |   0.9921599999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 16               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |           12           |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |         ('to_concat_skip_model', 25, 5)         |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |         ('to_concat_skip_model', 25, 33)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           16           |   1.8912430321797729   |   0.9915200000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 17               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |           12           |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |         ('to_conv_deeper_model', 33, 3)         |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |           ('to_add_skip_model', 1, 33)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           17           |   1.854608917236328    |        0.99236         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 18               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |           14           |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |         ('to_concat_skip_model', 1, 25)         |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |         ('to_concat_skip_model', 25, 33)        |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           18           |   1.7166316665709018   |        0.99276         |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 19               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |           12           |           ('to_add_skip_model', 1, 33)          |
# |                        |         ('to_conv_deeper_model', 33, 3)         |
# |                        |            ('to_wider_model', 23, 64)           |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |         ('to_concat_skip_model', 25, 44)        |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           19           |   1.7918546384200453   |   0.9928800000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 20               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |           12           |           ('to_add_skip_model', 1, 33)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |           ('to_wider_model', 14, 128)           |
# |                        |           ('to_add_skip_model', 44, 5)          |
# |                        |         ('to_concat_skip_model', 44, 5)         |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |         ('to_concat_skip_model', 1, 25)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           20           |   1.5238232619129122   |        0.99284         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 21               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |           12           |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |            ('to_wider_model', 33, 64)           |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           21           |   1.6877313347533345   |        0.99244         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 22               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |           12           |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |         ('to_conv_deeper_model', 33, 3)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |         ('to_concat_skip_model', 25, 44)        |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           22           |   1.5824460232630373   |   0.9927999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 23               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_dense_deeper_model', 23)          |
# |           14           |         ('to_concat_skip_model', 1, 25)         |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |         ('to_concat_skip_model', 25, 33)        |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |         ('to_conv_deeper_model', 33, 3)         |
# |                        |         ('to_conv_deeper_model', 33, 3)         |
# |                        |         ('to_concat_skip_model', 33, 59)        |
# |                        |            ('to_wider_model', 23, 64)           |
# |                        |           ('to_add_skip_model', 1, 59)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           23           |   1.525039524398744    |        0.99232         |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 24               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |           12           |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |         ('to_concat_skip_model', 1, 25)         |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |         ('to_concat_skip_model', 5, 44)         |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 25, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           24           |   1.6870101114735008   |   0.9927199999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 25               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |         ('to_conv_deeper_model', 33, 3)         |
# |           12           |            ('to_wider_model', 25, 64)           |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |            ('to_wider_model', 23, 64)           |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 9)           |
# |                        |         ('to_concat_skip_model', 25, 44)        |
# |                        |          ('to_add_skip_model', 25, 44)          |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |         ('to_concat_skip_model', 33, 44)        |
# |                        |          ('to_dense_deeper_model', 23)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           25           |   1.719707215577364    |        0.99236         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 26               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |           12           |            ('to_wider_model', 5, 64)            |
# |                        |           ('to_wider_model', 14, 128)           |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |         ('to_concat_skip_model', 44, 25)        |
# |                        |         ('to_concat_skip_model', 44, 5)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |         ('to_concat_skip_model', 44, 47)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           26           |    1.77620365973562    |   0.9921999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 27               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |           12           |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |           ('to_wider_model', 14, 128)           |
# |                        |            ('to_wider_model', 25, 64)           |
# |                        |         ('to_concat_skip_model', 1, 44)         |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           27           |   1.5135802499949933   |   0.9927199999999999   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 28               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |           12           |          ('to_conv_deeper_model', 1, 3)         |
# ...
# |                        |           ('to_wider_model', 25, 128)           |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |         ('to_concat_skip_model', 25, 33)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           37           |   1.7368993071839214   |   0.9921200000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 38               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |           12           |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |         ('to_concat_skip_model', 1, 25)         |
# |                        |            ('to_wider_model', 25, 64)           |
# |                        |           ('to_wider_model', 14, 128)           |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |          ('to_add_skip_model', 25, 33)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           38           |   1.5271565580740571   |   0.9928799999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 39               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |           12           |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |          ('to_dense_deeper_model', 23)          |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |          ('to_add_skip_model', 25, 33)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           39           |   1.700247228331864    |        0.99308         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 40               |
# +----------------------------------------------+
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |           12           |          ('to_conv_deeper_model', 5, 3)         |
# |                        |            ('to_wider_model', 25, 64)           |
# |                        |           ('to_add_skip_model', 1, 44)          |
# |                        |            ('to_wider_model', 23, 64)           |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |           ('to_add_skip_model', 5, 44)          |
# |                        |           ('to_wider_model', 23, 128)           |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           40           |   1.4123672362416984   |   0.9929600000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 41               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |           12           |          ('to_dense_deeper_model', 23)          |
# |                        |            ('to_wider_model', 5, 64)            |
# |                        |            ('to_wider_model', 25, 64)           |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |         ('to_concat_skip_model', 5, 50)         |
# |                        |         ('to_concat_skip_model', 25, 50)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           41           |   1.6087363936007022   |        0.99192         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 42               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |           12           |          ('to_conv_deeper_model', 5, 3)         |
# |                        |         ('to_concat_skip_model', 5, 44)         |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |            ('to_wider_model', 33, 64)           |
# |                        |         ('to_concat_skip_model', 1, 44)         |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |           ('to_add_skip_model', 5, 44)          |
# |                        |            ('to_wider_model', 25, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           42           |    1.67980521209538    |        0.99184         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 43               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |         ('to_conv_deeper_model', 33, 3)         |
# |           12           |           ('to_add_skip_model', 1, 25)          |
# |                        |            ('to_wider_model', 33, 64)           |
# |                        |         ('to_concat_skip_model', 33, 44)        |
# |                        |            ('to_wider_model', 25, 64)           |
# |                        |         ('to_concat_skip_model', 25, 5)         |
# |                        |         ('to_concat_skip_model', 33, 5)         |
# |                        |            ('to_wider_model', 5, 64)            |
# |                        |         ('to_concat_skip_model', 1, 25)         |
# |                        |         ('to_concat_skip_model', 25, 44)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           43           |   1.7644295062869788   |   0.9924799999999999   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 44               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_conv_deeper_model', 25, 3)         |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 33)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_add_skip_model', 44, 25)          |
# |                        |            ('to_wider_model', 44, 64)           |
# |           12           |           ('to_add_skip_model', 1, 33)          |
# |                        |           ('to_add_skip_model', 1, 5)           |
# |                        |           ('to_add_skip_model', 44, 5)          |
# |                        |           ('to_wider_model', 14, 128)           |
# |                        |            ('to_wider_model', 33, 64)           |
# |                        |         ('to_concat_skip_model', 1, 44)         |
# |                        |           ('to_add_skip_model', 25, 5)          |
# |                        |         ('to_concat_skip_model', 1, 33)         |
# |                        |           ('to_add_skip_model', 1, 25)          |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |            ('to_wider_model', 82, 64)           |
# |                        |           ('to_wider_model', 44, 128)           |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           44           |   1.687594161182642    |        0.99264         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 45               |
# +----------------------------------------------+
